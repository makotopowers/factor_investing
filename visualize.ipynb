# %%
# read in Data.xlsx into pandas dataframe
import pandas as pd
import numpy as np
import os
import sys
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('data/Data1.xlsx', sheet_name='Country equity returns')
# rename first column to 'Date'
df.rename(columns={df.columns[0]: 'Date'}, inplace=True)
# convert Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#         Date  MSCI Australia NR LCL  MSCI Canada NR LCL  MSCI France NR LCL  \
# 0 1970-01-31              -0.031330            0.024480            0.038060
# 1 1970-02-28              -0.011542            0.044393           -0.027917
# 2 1970-03-31              -0.003384            0.010206           -0.011684
# 3 1970-04-30              -0.111952           -0.114342           -0.059632
# 4 1970-05-31              -0.064832           -0.095029           -0.027265
#
#    MSCI Germany NR LCL  MSCI Italy NR LCL  MSCI Japan NR JPY  \
# 0            -0.048350           0.041000          -0.015471
# 1            -0.029265          -0.027224           0.012680
# 2             0.008811           0.035392           0.041257
# 3            -0.046194          -0.002880          -0.118091
# 4            -0.093870          -0.094636          -0.024622
#
#    MSCI Netherlands NR LCL  MSCI Spain NR LCL  MSCI United Kingdom NR LCL  \
# ...

# %%
df.dtypes
# Out:
# Date                          datetime64[ns]
# MSCI Australia NR LCL                float64
# MSCI Canada NR LCL                   float64
# MSCI France NR LCL                   float64
# MSCI Germany NR LCL                  float64
# MSCI Italy NR LCL                    float64
# MSCI Japan NR JPY                    float64
# MSCI Netherlands NR LCL              float64
# MSCI Spain NR LCL                    float64
# MSCI United Kingdom NR LCL           float64
# MSCI USA NR USD                      float64
# dtype: object

# %%
#plot 
plt.figure(figsize=(20, 15))
#plot the first 10 columns
for i in range(1, 11):
    plt.plot(df['Date'], df[df.columns[i]], label=df.columns[i])
plt.title('Country equity returns')
plt.xlabel('Date')
plt.ylabel('Return')
plt.legend()
plt.show()

# %%
def tick_B():
    pass

# %%
def tick_sigma():
    pass

# %%
def tick():
    # recalculate B matrix for each factor 
    B = tick_B()
    # recalculate the covariance matrix
    sigma = tick_sigma()

    # recalculate the weights for each factor portfolio
    #NOTE do 

    # put together the weights for each factor portfolio
    #NOTE do
